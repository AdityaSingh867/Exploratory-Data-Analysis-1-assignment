# %%
import pandas as pd

# %% [markdown]
# Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in
# predicting the quality of wine.

# %%
df = pd.read_csv('winequality-red.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# Q2. How did you handle missing data in the wine quality data set during the feature engineering process?
# Discuss the advantages and disadvantages of different imputation techniques.

# %% [markdown]
# # For handling the missing values we did some feature engineering process:
#
# - Delete the row
# - Delete the columns
# - Take median
# - Take mode
# - Take mean
#
#
# ## Delete the row
# ### Advantage
# - our missing value is handle.
# ### Disadvantage
# - Many data delete from row included missing value
#
# ## Delete the columns
# ### Advantage
# - our missing value is handle.
# ### Disadvantage
# - Many data delete from columns included missing value
#
# ## Take mean
# ### Advantage
# - our missing value is handle.
# ### Disadvantage
# - But if outliers is present in column or row so , mean is not work correctly

# %% [markdown]
# Q3. What are the key factors that affect students' performance in exams? How would you go about
# analyzing these factors using statistical techniques?

# %%
df_1 = pd.read_csv('stud.csv')

# %%
df_1.head(1)
# Out:
#    gender race_ethnicity parental_level_of_education     lunch  \
# 0  female        group B           bachelor's degree  standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74

# %%
df_1['average'] = df_1['math_score'] + df_1['writing_score'] + df_1['reading_score']/3

# %%
plt.figure(figsize=(15,6))
plt.subplots(1,2,figsize=(9,5))
plt.subplot(121)
plt.title('Male')
sns.histplot(data=df_1[df_1.gender=='male'] , x = 'average' , kde=True , color='g' , hue='lunch')
plt.subplot(122)
plt.title('Female')
sns.histplot(data=df_1[df_1.gender=='female'] , x = 'average' , kde=True , color='g' , hue='lunch')
# Out:
# <AxesSubplot: title={'center': 'Female'}, xlabel='average', ylabel='Count'>

# %% [markdown]
# #### There is key factor ( standard lunch ) that rduce the marks of student in both cases

# %% [markdown]
# Q4. Describe the process of feature engineering in the context of the student performance data set. How
# did you select and transform the variables for your model?

# %%
df_1.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %% [markdown]
# The context of the student performance dataset , I use average of 'math_score', 'reading_score','writing_score' to determine the perfomance of students.

# %% [markdown]
# ### I creat the new average column

# %%
df_1['Total_score'] = (df_1['math_score'] + df_1['writing_score'] + df_1['reading_score'])
df_1['average_score'] = df_1['Total_score']/3

# %%
df_1.head(3)
# Out:
#    gender race_ethnicity parental_level_of_education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
#
#    Total_score  average_score
# 0          218      72.666667
# 1          247      82.333333
# 2          278      92.666667

# %%
sns.histplot(data=df_1 , x = 'Total_score' , kde=True ,hue='lunch' )
# Out:
# <AxesSubplot: xlabel='Total_score', ylabel='Count'>

# %% [markdown]
# #### Student graph

# %% [markdown]
# Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution
# of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to
# these features to improve normality?

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
plt.title('This is fixed acidity graph' , fontweight = 'bold')
sns.kdeplot(data=df ,x = 'fixed acidity' , shade = True , color='#FF00D1')
# Out:
# <AxesSubplot: title={'center': 'This is fixed acidity graph'}, xlabel='fixed acidity', ylabel='Density'>

# %%
plt.title('This is volatile acidity graph' , fontweight = 'bold')
sns.kdeplot(data=df ,x = 'volatile acidity' , shade = True , color='#FF00D1')
# Out:
# <AxesSubplot: title={'center': 'This is volatile acidity graph'}, xlabel='volatile acidity', ylabel='Density'>

# %%
plt.title('This is citric acid graph' , fontweight = 'bold')
sns.kdeplot(data=df ,x = 'citric acid' , shade = True , color='#FF00D1')
# Out:
# <AxesSubplot: title={'center': 'This is citric acid graph'}, xlabel='citric acid', ylabel='Density'>

# %%
plt.title('This is residual sugar graph' , fontweight = 'bold')
sns.kdeplot(data=df ,x = 'residual sugar' , shade = True , color='#FF00D1')
# Out:
# <AxesSubplot: title={'center': 'This is residual sugar graph'}, xlabel='residual sugar', ylabel='Density'>

# %%
plt.title('This is chlorides graph' , fontweight = 'bold')
sns.kdeplot(data=df ,x = 'chlorides' , shade = True , color='#FF00D1')
# Out:
# <AxesSubplot: title={'center': 'This is chlorides graph'}, xlabel='chlorides', ylabel='Density'>

# %%
plt.title('This is free sulfur dioxide graph' , fontweight = 'bold')
sns.kdeplot(data=df ,x =  'free sulfur dioxide' , shade = True , color='#FF00D1')
# Out:
# <AxesSubplot: title={'center': 'This is free sulfur dioxide graph'}, xlabel='free sulfur dioxide', ylabel='Density'>

# %%
plt.title('This is total sulfur dioxide graph' , fontweight = 'bold')
sns.kdeplot(data=df ,x = 'total sulfur dioxide' , shade = True , color='#FF00D1')
# Out:
# <AxesSubplot: title={'center': 'This is total sulfur dioxide graph'}, xlabel='total sulfur dioxide', ylabel='Density'>

# %%
plt.title('This is density graph' , fontweight = 'bold')
sns.kdeplot(data=df ,x = 'density' , shade = True , color='#FF00D1')
# Out:
# <AxesSubplot: title={'center': 'This is density graph'}, xlabel='density', ylabel='Density'>

# %%
plt.title('This is pH graph' , fontweight = 'bold')
sns.kdeplot(data=df ,x = 'pH' , shade = True , color='#FF00D1')
# Out:
# <AxesSubplot: title={'center': 'This is pH graph'}, xlabel='pH', ylabel='Density'>

# %%
plt.title('This is sulphates graph' , fontweight = 'bold')
sns.kdeplot(data=df ,x = 'sulphates' , shade = True , color='#FF00D1')
# Out:
# <AxesSubplot: title={'center': 'This is sulphates graph'}, xlabel='sulphates', ylabel='Density'>

# %%
plt.title('This is alcohol graph' , fontweight = 'bold')
sns.kdeplot(data=df ,x = 'alcohol' , shade = True , color='#FF00D1')
# Out:
# <AxesSubplot: title={'center': 'This is alcohol graph'}, xlabel='alcohol', ylabel='Density'>

# %%
plt.title('This is quality graph' , fontweight = 'bold')
sns.kdeplot(data=df ,x = 'quality' , shade = True , color='#FF00D1')
# Out:
# <AxesSubplot: title={'center': 'This is quality graph'}, xlabel='quality', ylabel='Density'>

# %% [markdown]
# #### To improve the normality
# ##### 1 - fill the nan values by mean , median , mode
# ##### 2 - delete the duplicate values

# %% [markdown]
# Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of
# features. What is the minimum number of principal components required to explain 90% of the variance in
# the data?

# %%
df.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4               0.7          0.0             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5

# %%
from sklearn.decomposition import PCA

# %%
from sklearn.preprocessing import StandardScaler

# %%
std = StandardScaler()

# %%
x = df.drop('quality' , axis=1)

# %%
x_std = std.fit_transform(x)

# %%
x_std
# Out:
# array([[-0.52835961,  0.96187667, -1.39147228, ...,  1.28864292,
#         -0.57920652, -0.96024611],
#        [-0.29854743,  1.96744245, -1.39147228, ..., -0.7199333 ,
#          0.1289504 , -0.58477711],
#        [-0.29854743,  1.29706527, -1.18607043, ..., -0.33117661,
#         -0.04808883, -0.58477711],
#        ...,
#        [-1.1603431 , -0.09955388, -0.72391627, ...,  0.70550789,
#          0.54204194,  0.54162988],
#        [-1.39015528,  0.65462046, -0.77526673, ...,  1.6773996 ,
#          0.30598963, -0.20930812],
#        [-1.33270223, -1.21684919,  1.02199944, ...,  0.51112954,
#          0.01092425,  0.54162988]])

# %%
pca = PCA()

# %%
pca.fit(x_std)
# Out:
# PCA()

# %%
import numpy as np
cumulative_variance_ratio = np.cumsum(pca.explained_variance_ratio_)

# %%
n_components = np.argmax(cumulative_variance_ratio >= 0.9) + 1

# %%
cumulative_variance_ratio
# Out:
# array([0.28173931, 0.45682201, 0.59778051, 0.70807438, 0.79528275,
#        0.85524714, 0.90831906, 0.94676967, 0.97810077, 0.99458561,
#        1.        ])

# %%
print("Minimum number of principal components required to explain 90% of the variance:", n_components)
# Out:
# Minimum number of principal components required to explain 90% of the variance: 7
